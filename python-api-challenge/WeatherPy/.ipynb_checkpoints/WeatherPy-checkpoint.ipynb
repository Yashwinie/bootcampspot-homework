# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_key import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

#test calls to confirm I am getting random cities from all lat_lngs
print(city, lat_lng)
# Out:
# rikitea (-89.29850649734902, -133.19746563762646)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#request variables

url = "http://api.openweathermap.org/data/2.5/weather?"

#empty lists to store information that I need for dataframe and plots
city = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

n = 1

# %%
#test call to check format of json return

testcall = requests.get("http://api.openweathermap.org/data/2.5/weather?q=toronto&appid=a1349063ee99a929865315ed0494d173").json()
print(testcall)
# Out:
# {'cod': 429, 'message': 'Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price'}

# %%
#complete weather check and print log of each city as it is being processed

print("Beginning Data Retrieval")
print("------------------------")

for i in cities:
    try:
        #completing the call
        response = requests.get(f"{url}q={i}&appid={api_key}").json()
        
        #append parts of responses needed to fill out dataframe
        city.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
#         city_name = response["name"]
#         country_name = response["sys"]["country"]
        
        n=+1
        print(f"Processing City: {i}")
    except:
        print("City not found. Skipping...")
    continue
    
print("------------------------")
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing City 1: praia
# Processing City 1: arlit
# Processing City 1: namibe
# Processing City 1: puerto ayora
# Processing City 1: pochutla
# Processing City 1: kodiak
# Processing City 1: codrington
# Processing City 1: millau
# Processing City 1: yellowknife
# Processing City 1: cayenne
# Processing City 1: busselton
# Processing City 1: altay
# Processing City 1: awjilah
# Processing City 1: ushuaia
# Processing City 1: mahebourg
# Processing City 1: madang
# Processing City 1: chuy
# Processing City 1: cairns
# Processing City 1: fukue
# Processing City 1: new norfolk
# Processing City 1: atuona
# Processing City 1: mogadishu
# Processing City 1: rikitea
# Processing City 1: shambu
# Processing City 1: hithadhoo
# Processing City 1: dhandhuka
# Processing City 1: gazion
# Processing City 1: butaritari
# Processing City 1: hervey bay
# Processing City 1: souillac
# Processing City 1: saskylakh
# Processing City 1: bundaberg
# Processing City 1: bababe
# Processing City 1: hambantota
# Processing City 1: punta arenas
# Processing City 1: hilo
# Processing City 1: sobolevo
# Processing City 1: bluff
# Processing City 1: illoqqortoormiut
# Processing City 1: jamestown
# Processing City 1: upernavik
# Processing City 1: albany
# Processing City 1: inhambane
# Processing City 1: leticia
# Processing City 1: nizhneyansk
# Processing City 1: hermanus
# Processing City 1: vestmannaeyjar
# Processing City 1: tres picos
# Processing City 1: lasa
# Processing City 1: pueblo nuevo
# Processing City 1: sur
# Processing City 1: luyang
# Processing City 1: grindavik
# Processing City 1: hobart
# Processing City 1: kavaratti
# Processing City 1: ruteng
# Processing City 1: georgetown
# Processing City 1: yar-sale
# Processing City 1: yerbogachen
# Processing City 1: buala
# Processing City 1: thompson
# Processing City 1: port elizabeth
# Processing City 1: ugep
# Processing City 1: severo-kurilsk
# Processing City 1: savannah bight
# Processing City 1: cherskiy
# Processing City 1: bagdarin
# Processing City 1: olafsvik
# Processing City 1: manokwari
# Processing City 1: mataura
# Processing City 1: sitka
# Processing City 1: bathsheba
# Processing City 1: sentyabrskiy
# Processing City 1: nome
# Processing City 1: planaltina
# Processing City 1: salalah
# Processing City 1: chokurdakh
# Processing City 1: raudeberg
# Processing City 1: barrow
# Processing City 1: samusu
# Processing City 1: castro
# Processing City 1: belushya guba
# Processing City 1: constitucion
# Processing City 1: koster
# Processing City 1: bredasdorp
# Processing City 1: nikolskoye
# Processing City 1: mys shmidta
# Processing City 1: westport
# Processing City 1: tam ky
# Processing City 1: saldanha
# Processing City 1: longyearbyen
# Processing City 1: buluan
# Processing City 1: saint-louis
# Processing City 1: kapaa
# Processing City 1: omboue
# Processing City 1: tuktoyaktuk
# Processing City 1: molteno
# Processing City 1: vila
# Processing City 1: bonavista
# Processing City 1: maniitsoq
# Processing City 1: te anau
# Processing City 1: leningradskiy
# Processing City 1: naze
# Processing City 1: qaanaaq
# Processing City 1: nanortalik
# Processing City 1: pacific grove
# Processing City 1: kholmogory
# Processing City 1: ust-kuyga
# Processing City 1: mount isa
# Processing City 1: port keats
# Processing City 1: hope
# Processing City 1: muros
# Processing City 1: kununurra
# Processing City 1: dingle
# Processing City 1: cape town
# Processing City 1: mnogovershinnyy
# Processing City 1: bilma
# Processing City 1: saint-philippe
# Processing City 1: coquimbo
# Processing City 1: esperance
# Processing City 1: khatanga
# Processing City 1: wolomin
# Processing City 1: saint-pierre
# Processing City 1: port alfred
# Processing City 1: narsaq
# Processing City 1: sainte-maxime
# Processing City 1: sinjah
# Processing City 1: orotukan
# Processing City 1: shubarshi
# Processing City 1: lebu
# Processing City 1: kloulklubed
# Processing City 1: samarai
# Processing City 1: barquisimeto
# Processing City 1: coihaique
# Processing City 1: moindou
# Processing City 1: ancud
# Processing City 1: bulalacao
# Processing City 1: kerema
# Processing City 1: gat
# Processing City 1: jiayuguan
# Processing City 1: luderitz
# Processing City 1: le port
# Processing City 1: san juan de uraba
# Processing City 1: pedreiras
# Processing City 1: chopovychi
# Processing City 1: trelew
# Processing City 1: zhuanghe
# Processing City 1: camabatela
# Processing City 1: yulara
# Processing City 1: margate
# Processing City 1: ust-bolsheretsk
# Processing City 1: rudbar
# Processing City 1: kaitangata
# Processing City 1: bajil
# Processing City 1: polyarnyy
# Processing City 1: staryy nadym
# Processing City 1: mattru
# Processing City 1: avarua
# Processing City 1: bubaque
# Processing City 1: tsihombe
# Processing City 1: riverton
# Processing City 1: paithan
# Processing City 1: domna
# Processing City 1: waitati
# Processing City 1: lithgow
# Processing City 1: havoysund
# Processing City 1: bheramara
# Processing City 1: usak
# Processing City 1: masallatah
# Processing City 1: wonji
# Processing City 1: paranhos
# Processing City 1: cidreira
# Processing City 1: beringovskiy
# Processing City 1: east london
# Processing City 1: pivka
# Processing City 1: amarillo
# Processing City 1: carlsbad
# Processing City 1: wajima
# Processing City 1: tasiilaq
# Processing City 1: hirara
# Processing City 1: druzhba
# Processing City 1: kracheh
# Processing City 1: vaini
# Processing City 1: baoqing
# Processing City 1: karatsu
# Processing City 1: samaipata
# Processing City 1: walvis bay
# Processing City 1: mataruska banja
# Processing City 1: taolanaro
# Processing City 1: gillette
# Processing City 1: mehamn
# Processing City 1: aklavik
# Processing City 1: shimoda
# Processing City 1: umba
# Processing City 1: vardo
# Processing City 1: siderno
# Processing City 1: broken hill
# Processing City 1: deniliquin
# Processing City 1: sumbawa
# Processing City 1: seoul
# Processing City 1: verkhnevilyuysk
# Processing City 1: zirgan
# Processing City 1: ribeira grande
# Processing City 1: amderma
# Processing City 1: ca mau
# Processing City 1: bethel
# Processing City 1: chagda
# Processing City 1: carnarvon
# Processing City 1: bartica
# Processing City 1: vwawa
# Processing City 1: norman wells
# Processing City 1: twentynine palms
# Processing City 1: peterhead
# Processing City 1: port-gentil
# Processing City 1: sibu
# Processing City 1: dinguiraye
# Processing City 1: karakose
# Processing City 1: camacha
# Processing City 1: massape
# Processing City 1: hovd
# Processing City 1: greymouth
# Processing City 1: cabo san lucas
# Processing City 1: ponta delgada
# Processing City 1: namatanai
# Processing City 1: komsomolskiy
# Processing City 1: grand gaube
# Processing City 1: navsari
# Processing City 1: pangnirtung
# Processing City 1: marawi
# Processing City 1: port blair
# Processing City 1: saint-joseph
# Processing City 1: amahai
# Processing City 1: tiksi
# Processing City 1: ambanja
# Processing City 1: utiel
# Processing City 1: udachnyy
# Processing City 1: camopi
# Processing City 1: dikson
# Processing City 1: faanui
# Processing City 1: tessalit
# Processing City 1: russell
# Processing City 1: bambous virieux
# Processing City 1: chernyshevskiy
# Processing City 1: arraial do cabo
# Processing City 1: kuala terengganu
# Processing City 1: dudinka
# Processing City 1: ruatoria
# Processing City 1: ihosy
# Processing City 1: kruisfontein
# Processing City 1: pilu
# Processing City 1: lukovetskiy
# Processing City 1: caravelas
# Processing City 1: kalga
# Processing City 1: grand river south east
# Processing City 1: kidal
# Processing City 1: geraldton
# Processing City 1: rangapara
# Processing City 1: damaturu
# Processing City 1: xichang
# Processing City 1: anzio
# Processing City 1: korla
# Processing City 1: clyde river
# Processing City 1: skibbereen
# Processing City 1: zakamensk
# Processing City 1: conde
# Processing City 1: airai
# Processing City 1: marktoberdorf
# Processing City 1: los llanos de aridane
# Processing City 1: stabat
# Processing City 1: ahipara
# Processing City 1: lorengau
# Processing City 1: brae
# Processing City 1: kamaishi
# Processing City 1: bandarbeyla
# Processing City 1: sambava
# Processing City 1: edd
# Processing City 1: ketchikan
# Processing City 1: the valley
# Processing City 1: sao raimundo nonato
# Processing City 1: omsukchan
# Processing City 1: oranjemund
# Processing City 1: orsta
# Processing City 1: asbe teferi
# Processing City 1: kokstad
# Processing City 1: asayita
# Processing City 1: saleaula
# Processing City 1: luau
# Processing City 1: hofn
# Processing City 1: mezinovskiy
# Processing City 1: lompoc
# Processing City 1: saint-augustin
# Processing City 1: okha
# Processing City 1: alofi
# Processing City 1: rocha
# Processing City 1: turmalina
# Processing City 1: tautira
# Processing City 1: himatnagar
# Processing City 1: vaitupu
# Processing City 1: gamboula
# Processing City 1: guangyuan
# Processing City 1: ostrovnoy
# Processing City 1: kutum
# Processing City 1: visnes
# Processing City 1: bengkulu
# Processing City 1: ternate
# Processing City 1: sinnar
# Processing City 1: siemiatycze
# Processing City 1: inirida
# Processing City 1: hinton
# Processing City 1: bima
# Processing City 1: talnakh
# Processing City 1: altamont
# Processing City 1: tokonou
# Processing City 1: yeppoon
# Processing City 1: trairi
# Processing City 1: port hedland
# Processing City 1: egvekinot
# Processing City 1: barentsburg
# Processing City 1: katsuura
# Processing City 1: bintulu
# Processing City 1: attawapiskat
# Processing City 1: marzuq
# Processing City 1: lere
# Processing City 1: alice springs
# Processing City 1: karaul
# Processing City 1: teshie
# Processing City 1: mar del plata
# Processing City 1: zapolyarnyy
# Processing City 1: martaban
# Processing City 1: isangel
# Processing City 1: college
# Processing City 1: lodeynoye pole
# Processing City 1: bad freienwalde
# Processing City 1: ondorhaan
# Processing City 1: toul
# Processing City 1: fortuna
# Processing City 1: minsk
# Processing City 1: delvine
# Processing City 1: eirunepe
# Processing City 1: kapuskasing
# Processing City 1: padang
# Processing City 1: moron
# Processing City 1: sao jose da coroa grande
# Processing City 1: new philadelphia
# Processing City 1: chapais
# Processing City 1: mikhaylovskoye
# Processing City 1: west wendover
# Processing City 1: teknaf
# Processing City 1: marang
# Processing City 1: salinopolis
# Processing City 1: paamiut
# Processing City 1: zhangye
# Processing City 1: matay
# Processing City 1: belyy yar
# Processing City 1: parobe
# Processing City 1: port hardy
# Processing City 1: baruun-urt
# Processing City 1: onalaska
# Processing City 1: bogorodskoye
# Processing City 1: skagastrond
# Processing City 1: key west
# Processing City 1: svetlyy
# Processing City 1: gravdal
# Processing City 1: tumannyy
# Processing City 1: maloshuyka
# Processing City 1: jieshi
# Processing City 1: puerto baquerizo moreno
# Processing City 1: aljezur
# Processing City 1: port macquarie
# Processing City 1: islamabad
# Processing City 1: broome
# Processing City 1: ngunguru
# Processing City 1: rovaniemi
# Processing City 1: ipilan
# Processing City 1: nguiu
# Processing City 1: kargil
# Processing City 1: ulladulla
# Processing City 1: half moon bay
# Processing City 1: hamilton
# Processing City 1: itzican
# Processing City 1: gigmoto
# Processing City 1: christchurch
# Processing City 1: morgan city
# Processing City 1: ayer itam
# Processing City 1: baykit
# Processing City 1: bethlehem
# Processing City 1: puerto madero
# Processing City 1: fort nelson
# Processing City 1: upata
# Processing City 1: aracati
# Processing City 1: oranjestad
# Processing City 1: itaituba
# Processing City 1: yaring
# Processing City 1: faya
# Processing City 1: burnie
# Processing City 1: spas-demensk
# Processing City 1: rungata
# Processing City 1: malakal
# Processing City 1: rokytne
# Processing City 1: tulsipur
# Processing City 1: ossora
# Processing City 1: bowen
# Processing City 1: victoria
# Processing City 1: soyo
# Processing City 1: mbuguni
# Processing City 1: honiara
# Processing City 1: laguna
# Processing City 1: trabzon
# Processing City 1: moroni
# Processing City 1: cozumel
# Processing City 1: pala
# Processing City 1: oktyabrskiy
# Processing City 1: chumikan
# Processing City 1: chute-aux-outardes
# Processing City 1: gari
# Processing City 1: buta
# Processing City 1: torbay
# Processing City 1: houma
# Processing City 1: krutinka
# Processing City 1: himora
# Processing City 1: bilibino
# Processing City 1: namtsy
# Processing City 1: yuncheng
# Processing City 1: ksenyevka
# Processing City 1: ambilobe
# Processing City 1: lenki
# Processing City 1: opuwo
# Processing City 1: palabuhanratu
# Processing City 1: san patricio
# Processing City 1: hay river
# Processing City 1: meyungs
# Processing City 1: gisborne
# Processing City 1: indianola
# Processing City 1: uthal
# Processing City 1: haverhill
# Processing City 1: labuhan
# Processing City 1: wulanhaote
# Processing City 1: klaksvik
# Processing City 1: karasjok
# Processing City 1: xuddur
# Processing City 1: ningan
# Processing City 1: namie
# Processing City 1: ponta do sol
# Processing City 1: saint george
# Processing City 1: dwarka
# Processing City 1: sena madureira
# Processing City 1: rizhao
# Processing City 1: haines junction
# Processing City 1: santa maria del oro
# Processing City 1: anahuac
# Processing City 1: filadelfia
# Processing City 1: axim
# Processing City 1: karwar
# Processing City 1: maceio
# Processing City 1: yagodnoye
# Processing City 1: blagoyevo
# Processing City 1: chalus
# Processing City 1: waipawa
# Processing City 1: boras
# Processing City 1: lusaka
# Processing City 1: dera ismail khan
# Processing City 1: provideniya
# Processing City 1: abakan
# Processing City 1: mantenopolis
# Processing City 1: columbus
# Processing City 1: chancay
# Processing City 1: novyy urengoy
# Processing City 1: nerchinskiy zavod
# Processing City 1: kostino
# Processing City 1: vanavara
# Processing City 1: aklera
# Processing City 1: cabedelo
# Processing City 1: shenjiamen
# Processing City 1: vanderhoof
# Processing City 1: les cayes
# Processing City 1: nara
# Processing City 1: rantepao
# Processing City 1: huambo
# Processing City 1: lavrentiya
# Processing City 1: rio branco
# Processing City 1: cabinda
# Processing City 1: wembley
# Processing City 1: banyo
# Processing City 1: luanda
# Processing City 1: dehui
# Processing City 1: methoni
# Processing City 1: joshimath
# Processing City 1: olinda
# Processing City 1: qaqortoq
# Processing City 1: san juan nepomuceno
# Processing City 1: ipora
# Processing City 1: sangar
# Processing City 1: sao filipe
# Processing City 1: porto belo
# Processing City 1: luganville
# Processing City 1: goderich
# Processing City 1: kabinda
# Processing City 1: hopelchen
# Processing City 1: humaita
# Processing City 1: yarmouth
# Processing City 1: ilanskiy
# Processing City 1: uturoa
# Processing City 1: le vauclin
# Processing City 1: calama
# Processing City 1: nioki
# Processing City 1: comodoro rivadavia
# Processing City 1: seymchan
# Processing City 1: khormuj
# Processing City 1: hasaki
# Processing City 1: acajutla
# Processing City 1: nuuk
# Processing City 1: nizhniy odes
# Processing City 1: pisco
# Processing City 1: gangotri
# Processing City 1: porosozero
# Processing City 1: mizdah
# Processing City 1: blonduos
# Processing City 1: tuatapere
# Processing City 1: weinan
# Processing City 1: pompeu
# Processing City 1: moose factory
# Processing City 1: witu
# Processing City 1: doka
# Processing City 1: roros
# Processing City 1: springdale
# Processing City 1: kiomboi
# Processing City 1: kavieng
# Processing City 1: laramie
# Processing City 1: niquelandia
# Processing City 1: zaozerne
# Processing City 1: xapuri
# Processing City 1: tsaratanana
# Processing City 1: baturaja
# Processing City 1: bonfim
# Processing City 1: sibolga
# Processing City 1: ust-nera
# Processing City 1: tutoia
# Processing City 1: viedma
# Processing City 1: humberto de campos
# Processing City 1: paka
# Processing City 1: sorong
# Processing City 1: lata
# Processing City 1: jasdan
# Processing City 1: hualmay
# Processing City 1: xihe
# Processing City 1: ormara
# Processing City 1: tubruq
# Processing City 1: iskar
# Processing City 1: adrar
# Processing City 1: kenai
# Processing City 1: kasane
# Processing City 1: polunochnoye
# Processing City 1: champerico
# Processing City 1: boshnyakovo
# Processing City 1: eloy
# Processing City 1: haibowan
# Processing City 1: shu
# Processing City 1: wabrzezno
# Processing City 1: marcona
# Processing City 1: sieradz
# Processing City 1: alenquer
# Processing City 1: lima
# Processing City 1: tazovskiy
# Processing City 1: port lincoln
# Processing City 1: umm lajj
# Processing City 1: srednekolymsk
# Processing City 1: carutapera
# Processing City 1: takaka
# Processing City 1: alzamay
# Processing City 1: tanout
# Processing City 1: mayumba
# Processing City 1: pevek
# Processing City 1: bonthe
# Processing City 1: vila franca do campo
# Processing City 1: kamalia
# Processing City 1: mayya
# Processing City 1: brownwood
# Processing City 1: san quintin
# Processing City 1: nhulunbuy
# Processing City 1: watsa
# Processing City 1: tommot
# Processing City 1: dinar
# Processing City 1: makakilo city
# Processing City 1: petropavlovsk-kamchatskiy
# Processing City 1: zhanaozen
# Processing City 1: gashua
# Processing City 1: babu
# Processing City 1: dauriya
# Processing City 1: parkes
# Processing City 1: wonthaggi
# Processing City 1: along
# Processing City 1: san ignacio
# Processing City 1: daru
# Processing City 1: awbari
# Processing City 1: bokoro
# Processing City 1: biak
# Processing City 1: sokoni
# Processing City 1: kathu
# Processing City 1: scituate
# Processing City 1: garowe
# Processing City 1: nagato
# Processing City 1: rawson
# Processing City 1: denpasar
# Processing City 1: khelyulya
# Processing City 1: sisimiut
# Processing City 1: sorland
# Processing City 1: maragogi
# Processing City 1: temerloh
# Processing City 1: tual
# Processing City 1: skelleftea
# Processing City 1: elko
# Processing City 1: san cristobal
# Processing City 1: calubcub
# Processing City 1: vao
# Processing City 1: louisbourg
# Processing City 1: anadyr
# Processing City 1: piacabucu
# Processing City 1: sergeyevka
# Processing City 1: sinnamary
# Processing City 1: poso
# Processing City 1: lages
# Processing City 1: marsaxlokk
# Processing City 1: mamakan
# Processing City 1: kalemie
# Processing City 1: hudson bay
# Processing City 1: saint anthony
# Processing City 1: tilichiki
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
